# %% [markdown]
# # Training a model with an image datasets in fastai
# Walkthrough of how to train a deep learning model in fastai with a curated image dataset

# %%
# imports for notebook boilerplate
# !pip install -Uqq fastbook
import fastbook
from fastbook import *
from fastai.vision.all import *

# %%
# set up the notebook for fast.ai
fastbook.setup_book()

# %%
# ingest the curated image dataset FLOWERS
path = untar_data(URLs.FLOWERS)

# %%
# examine the directory structure of the dataset
path.ls()
# Out:
# (#4) [Path('/storage/data/oxford-102-flowers/test.txt'),Path('/storage/data/oxford-102-flowers/jpg'),Path('/storage/data/oxford-102-flowers/valid.txt'),Path('/storage/data/oxford-102-flowers/train.txt')]

# %%
# ingest the train dataset list into a Pandas dataframe

df_valid = pd.read_csv(path/'valid.txt', header=None)
df_valid.head()
# Out:
#                         0
# 0  jpg/image_04467.jpg 89
# 1  jpg/image_07129.jpg 44
# 2   jpg/image_05166.jpg 4
# 3  jpg/image_07002.jpg 34
# 4  jpg/image_02007.jpg 79

# %%
# examine the jpg subdirectory
(path/'jpg').ls()
# Out:
# (#8189) [Path('/storage/data/oxford-102-flowers/jpg/image_05656.jpg'),Path('/storage/data/oxford-102-flowers/jpg/image_00310.jpg'),Path('/storage/data/oxford-102-flowers/jpg/image_01044.jpg'),Path('/storage/data/oxford-102-flowers/jpg/image_07917.jpg'),Path('/storage/data/oxford-102-flowers/jpg/image_03142.jpg'),Path('/storage/data/oxford-102-flowers/jpg/image_01467.jpg'),Path('/storage/data/oxford-102-flowers/jpg/image_02862.jpg'),Path('/storage/data/oxford-102-flowers/jpg/image_01222.jpg'),Path('/storage/data/oxford-102-flowers/jpg/image_02615.jpg'),Path('/storage/data/oxford-102-flowers/jpg/image_05805.jpg')...]

# %%
# take a look at one of the images
img_files = get_image_files(path)
img = PILImage.create(img_files[100])
img
# Out:
# PILImage mode=RGB size=667x500

# %%
# display a thumbnail of the image
img.to_thumb(180)
# Out:
# <PIL.Image.Image image mode=RGB size=180x135 at 0x7F3B5194EEE0>

# %%
# ingest the curated image localization dataset BIWI_HEAD_POSE
path = untar_data(URLs.BIWI_HEAD_POSE)

# %%
# examine the directory structure of the dataset
path.ls()
# Out:
# (#50) [Path('/storage/data/biwi_head_pose/16'),Path('/storage/data/biwi_head_pose/10.obj'),Path('/storage/data/biwi_head_pose/03'),Path('/storage/data/biwi_head_pose/16.obj'),Path('/storage/data/biwi_head_pose/19'),Path('/storage/data/biwi_head_pose/01'),Path('/storage/data/biwi_head_pose/20.obj'),Path('/storage/data/biwi_head_pose/13'),Path('/storage/data/biwi_head_pose/05.obj'),Path('/storage/data/biwi_head_pose/21')...]

# %%
# examine one of the subdirectories
(path/"05").ls()
# Out:
# (#1894) [Path('/storage/data/biwi_head_pose/05/frame_00708_pose.txt'),Path('/storage/data/biwi_head_pose/05/frame_00182_rgb.jpg'),Path('/storage/data/biwi_head_pose/05/frame_00874_rgb.jpg'),Path('/storage/data/biwi_head_pose/05/frame_00430_pose.txt'),Path('/storage/data/biwi_head_pose/05/frame_00304_rgb.jpg'),Path('/storage/data/biwi_head_pose/05/frame_00525_rgb.jpg'),Path('/storage/data/biwi_head_pose/05/frame_00103_rgb.jpg'),Path('/storage/data/biwi_head_pose/05/frame_00817_rgb.jpg'),Path('/storage/data/biwi_head_pose/05/frame_00091_pose.txt'),Path('/storage/data/biwi_head_pose/05/frame_00409_pose.txt')...]

# %%
# take a look at one of the images
img_files = get_image_files(path/'10')
img = PILImage.create(img_files[8])
img.to_thumb(180)
# Out:
# <PIL.Image.Image image mode=RGB size=180x135 at 0x7F3BC90187C0>

# %%
# take a look at one of the pose text files
path/'05/frame_00191_pose.txt'
# Out:
# Path('/storage/data/biwi_head_pose/05/frame_00191_pose.txt')

# %%
# ingest one of the pose text files into a Pandas dataframe
df_pose = pd.read_csv(path/'05/frame_00191_pose.txt', header=None)
df_pose.head()
# Out:
#                                0
# 0   0.860993 0.162766 -0.481869
# 1  0.00729371 0.943363 0.331682
# 2   0.508564 -0.289091 0.811042
# 3       116.403 12.1671 871.544
